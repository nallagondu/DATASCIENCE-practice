# %% [markdown]
# <a href="https://colab.research.google.com/github/nallagondu/DATASCIENCE-practice/blob/main/DataTrained__Decision_Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Foursteps-tech/Machine_Learning.git
# Out:
# Cloning into 'Machine_Learning'...
# remote: Enumerating objects: 2284, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 2284 (delta 42), reused 82 (delta 27), pack-reused 2173
# Receiving objects: 100% (2284/2284), 84.04 MiB | 21.31 MiB/s, done.
# Resolving deltas: 100% (51/51), done.
# Updating files: 100% (2789/2789), done.

# %%
from pandas import read_csv
import numpy as np
import sklearn
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import tree

# %%
dataframe = read_csv("Machine_Learning/Classification/pima-indians-diabetes.csv",header=None)
dataframe.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
dataset = dataframe.values
data = dataset[:,1:8].astype(float)
labels = dataset[:,8]

# %%
(trainData, testData, trainLabels, testLabels) = train_test_split(np.array(data),
	np.array(labels), test_size=0.25, random_state=42)

# %%
#splitter = best, random | max_features = int, auto, log, none | max_depth = int
model = DecisionTreeClassifier(random_state=42,criterion='gini',max_features=4, max_depth =8)

# %%
model.fit(trainData, trainLabels)
# Out:
# DecisionTreeClassifier(max_depth=8, max_features=4, random_state=42)

# %%
print(model.score(trainData, trainLabels))
# Out:
# 0.9079861111111112

# %%
print(model.score(testData, testLabels))
# Out:
# 0.6770833333333334

# %%
predictions = model.predict(testData)

# %%
print(classification_report(testLabels, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.73      0.74       123
#          1.0       0.55      0.58      0.56        69
#
#     accuracy                           0.68       192
#    macro avg       0.65      0.66      0.65       192
# weighted avg       0.68      0.68      0.68       192

# %%
fig = plt.figure(figsize=(45,40))
fig = tree.plot_tree(model)
plt.show()
